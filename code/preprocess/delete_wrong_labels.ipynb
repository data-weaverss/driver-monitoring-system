# %%
import pandas as pd
import numpy as np
import os

# %%
# 기존 dataframe 복사

old_path = '/content/drive/MyDrive/DMS/data/splits/24frame_windows/final_train.csv'
new_path = '/content/drive/MyDrive/DMS/data/splits/24frame_windows/final_train_v1.csv'

os.rename(old_path, new_path)

# %%
final_train = pd.read_csv(new_path)
# Out:
# <ipython-input-8-748c95b0125f>:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   final_train = pd.read_csv(new_path)

# %%
print(f"before deleting: {len(final_train)}")
final_train = final_train[
    ~((final_train['label'] == 'text') &
    (final_train['clip_id'] == 'gE-30(File20)_s2_face_2019-03-15-10;43;40_30_2.avi') &
    (final_train['groups_24'] == 2))
]
print(f"after deleting: {len(final_train)}")
# Out:
# before deleting: 82224
# after deleting: 82200

# %%
print(f"before deleting: {len(final_train)}")
final_train = final_train[
    ~((final_train['label'] == 'text') &
    (final_train['clip_id'] == 'gF-22(File21)_s4_face_2019-03-25-14;22;00_22_0.avi') &
    (final_train['groups_24'] == 2))
]
print(f"after deleting: {len(final_train)}")
# Out:
# before deleting: 82200
# after deleting: 82176

# %%
print(f"before deleting: {len(final_train)}")
final_train = final_train[
    ~((final_train['label'] == 'yawn') &
    (final_train['clip_id'] == 'gC-12(File12)_s5_face_2019-03-14-09;56;52_12_0.avi'))
]
print(f"after deleting: {len(final_train)}")
# Out:
# before deleting: 82176
# after deleting: 82152

# %%
print(f"before deleting: {len(final_train)}")
final_train = final_train[
    ~((final_train['label'] == 'yawn') &
    (final_train['clip_id'] == 'gC-12(File12)_s5_face_2019-03-14-09;56;52_12_1.avi'))
]
print(f"after deleting: {len(final_train)}")
# Out:
# before deleting: 82152
# after deleting: 82128

# %%
print(f"before deleting: {len(final_train)}")
final_train = final_train[
    ~((final_train['label'] == 'yawn') &
    (final_train['clip_id'] == 'gC-14(File14)_s5_face_2019-03-12-09;18;58_14_0.avi'))
]
print(f"after deleting: {len(final_train)}")
# Out:
# before deleting: 82128
# after deleting: 82104

# %%
print(f"before deleting: {len(final_train)}")
final_train = final_train[
    ~((final_train['label'] == 'yawn') &
    (final_train['clip_id'] == 'gC-14(File14)_s5_face_2019-03-12-09;18;58_14_1.avi'))
]
print(f"after deleting: {len(final_train)}")
# Out:
# before deleting: 82104
# after deleting: 82080

# %%
print(f"before deleting: {len(final_train)}")
final_train = final_train[
    ~((final_train['label'] == 'yawn') &
    (final_train['clip_id'] == 'gC-15(File15)_s5_face_2019-03-12-11;03;23_15_0.avi'))
]
print(f"after deleting: {len(final_train)}")
# Out:
# before deleting: 82080
# after deleting: 82056

# %%
print(f"before deleting: {len(final_train)}")
final_train = final_train[
    ~((final_train['label'] == 'yawn') &
    (final_train['clip_id'] == 'gC-15(File15)_s5_face_2019-03-12-11;03;23_15_1.avi'))
]
print(f"after deleting: {len(final_train)}")
# Out:
# before deleting: 82056
# after deleting: 82032

# %%
print(f"before deleting: {len(final_train)}")
final_train = final_train[
    ~((final_train['label'] == 'normal') &
    (final_train['clip_id'] == '28-MaleNoGlasses-Yawning-clip-2') &
    (final_train['groups_24'] == 0))
]
print(f"after deleting: {len(final_train)}")
# Out:
# before deleting: 82032
# after deleting: 82008

# %%
print(f"before deleting: {len(final_train)}")
final_train = final_train[
    ~((final_train['label'] == 'normal') &
    (final_train['clip_id'] == '20-MaleGlasses-Talking&yawning-clip-4'))
]
print(f"after deleting: {len(final_train)}")
# Out:
# before deleting: 82008
# after deleting: 81912

# %%
print(f"before deleting: {len(final_train)}")
final_train = final_train[
    ~((final_train['label'] == 'normal') &
    (final_train['clip_id'] == 'gE-28(File18)_s2_face_2019-03-15-10;12;30_28_1.avi'))
]
print(f"after deleting: {len(final_train)}")
# Out:
# before deleting: 81912
# after deleting: 81816

# %%
print(f"before deleting: {len(final_train)}")
final_train = final_train[
    ~((final_train['label'] == 'normal') &
    (final_train['clip_id'] == 'gZ-33(File27)_s1_face_2019-04-08-16;18;54_33_25.avi'))
]
print(f"after deleting: {len(final_train)}")
# Out:
# before deleting: 81816
# after deleting: 81792

# %%
print(f"before deleting: {len(final_train)}")
final_train = final_train[
    ~((final_train['label'] == 'normal') &
    (final_train['clip_id'] == '3-MaleGlasses-Yawning-clip-0'))
]
print(f"after deleting: {len(final_train)}")
# Out:
# before deleting: 81792
# after deleting: 81696

# %%
print(f"before deleting: {len(final_train)}")
final_train = final_train[
    ~((final_train['label'] == 'normal') &
    (final_train['clip_id'] == 'gZ-33(File27)_s2_face_2019-04-08-16;09;44_33_11.avi'))
]
print(f"after deleting: {len(final_train)}")
# Out:
# before deleting: 81696
# after deleting: 81648

# %%
final_train.to_csv(old_path, index=False)

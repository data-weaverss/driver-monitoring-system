# %% [markdown]
# # Yaw DD 클립 영상별 총 프레임 수와 FPS

# %% [markdown]
# ## 총 프레임 수

# %%
import os
import cv2
import pandas as pd

def get_video_frame_count(video_path):
    """비디오 파일의 총 프레임 개수를 반환"""
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"⚠️ 파일을 열 수 없음: {video_path}")
        return None
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))  # 총 프레임 수
    cap.release()
    return frame_count

def analyze_videos_recursively(directory):
    """디렉토리 및 하위 폴더 내 모든 비디오 파일의 프레임 개수를 계산"""
    video_data = []

    # os.walk()를 사용하여 모든 하위 디렉토리를 탐색
    for root, _, files in os.walk(directory):
        for filename in files:
            video_path = os.path.join(root, filename)

            # 비디오 파일만 처리 (.mp4, .avi, .mov 등 추가 가능)
            if filename.lower().endswith(('.mp4', '.avi', '.mov', '.mkv', '.flv', '.wmv')):
                frame_count = get_video_frame_count(video_path)
                if frame_count is not None:
                    video_data.append({
                        "directory": root,    # 파일이 위치한 디렉토리 경로
                        "filename": filename, # 비디오 파일명
                        "frame_count": frame_count # 비디오 프레임 수
                    })

    # 데이터프레임 생성
    df = pd.DataFrame(video_data)
    return df

# 사용 예시
video_directory = "/content/drive/MyDrive/DMS/data/YawDD dataset/clipped"  # 비디오가 저장된 디렉토리 경로
df = analyze_videos_recursively(video_directory)

# 결과 출력
df
# Out:
#                                              directory  \
# 0    /content/drive/MyDrive/DMS/data/YawDD dataset/...
# 1    /content/drive/MyDrive/DMS/data/YawDD dataset/...
# 2    /content/drive/MyDrive/DMS/data/YawDD dataset/...
# 3    /content/drive/MyDrive/DMS/data/YawDD dataset/...
# 4    /content/drive/MyDrive/DMS/data/YawDD dataset/...
# ..                                                 ...
# 414  /content/drive/MyDrive/DMS/data/YawDD dataset/...
# 415  /content/drive/MyDrive/DMS/data/YawDD dataset/...
# 416  /content/drive/MyDrive/DMS/data/YawDD dataset/...
# 417  /content/drive/MyDrive/DMS/data/YawDD dataset/...
# 418  /content/drive/MyDrive/DMS/data/YawDD dataset/...
#
#                                    filename  frame_count
# 0        3-MaleNoGlasses-Yawning-clip-1.avi          180
# 1         11-MaleGlasses-Yawning-clip-0.avi          120
# 2         12-MaleGlasses-Yawning-clip-0.avi          120
# 3         12-MaleGlasses-Yawning-clip-2.avi          240
# 4         12-MaleGlasses-Yawning-clip-4.avi          121
# ..                                      ...          ...
# 414   39-FemaleNoGlasses-Yawning-clip-0.avi           90
# 415     41-FemaleGlasses-Yawning-clip-0.avi           60
# 416   40-FemaleNoGlasses-Yawning-clip-1.avi          120
# 417  42-FemaleSunGlasses-Yawning-clip-1.avi           60
# 418   43-FemaleNoGlasses-Yawning-clip-1.avi           60
#
# [419 rows x 3 columns]

# %% [markdown]
# ## FPS

# %%
import os
import cv2
import pandas as pd

def get_video_info(video_path):
    """비디오 파일의 총 프레임 개수 및 FPS를 반환"""
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"⚠️ 파일을 열 수 없음: {video_path}")
        return None, None
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))  # 총 프레임 수
    fps = cap.get(cv2.CAP_PROP_FPS)  # FPS (초당 프레임 수)
    cap.release()
    return frame_count, fps

def analyze_videos_with_fps(directory):
    """디렉토리 및 하위 폴더 내 모든 비디오 파일의 프레임 개수와 FPS 계산"""
    video_data = []

    # os.walk()를 사용하여 모든 하위 디렉토리 탐색
    for root, _, files in os.walk(directory):
        for filename in files:
            video_path = os.path.join(root, filename)

            # 비디오 파일만 처리 (.mp4, .avi, .mov 등 추가 가능)
            if filename.lower().endswith(('.mp4', '.avi', '.mov', '.mkv', '.flv', '.wmv')):
                frame_count, fps = get_video_info(video_path)
                if frame_count is not None and fps is not None:
                    video_data.append({
                        "directory": root,    # 파일이 위치한 디렉토리 경로
                        "filename": filename, # 비디오 파일명
                        "frame_count": frame_count, # 비디오 총 프레임 개수
                        "fps": round(fps, 2)  # FPS (소수점 2자리로 반올림)
                    })

    # 데이터프레임 생성
    df = pd.DataFrame(video_data)
    return df

# 사용 예시
video_directory = "/content/drive/MyDrive/DMS/data/YawDD dataset/clipped"  # 비디오가 저장된 최상위 디렉토리 경로
df = analyze_videos_with_fps(video_directory)

# 결과 출력
df
# Out:
#                                              directory  \
# 0    /content/drive/MyDrive/DMS/data/YawDD dataset/...
# 1    /content/drive/MyDrive/DMS/data/YawDD dataset/...
# 2    /content/drive/MyDrive/DMS/data/YawDD dataset/...
# 3    /content/drive/MyDrive/DMS/data/YawDD dataset/...
# 4    /content/drive/MyDrive/DMS/data/YawDD dataset/...
# ..                                                 ...
# 414  /content/drive/MyDrive/DMS/data/YawDD dataset/...
# 415  /content/drive/MyDrive/DMS/data/YawDD dataset/...
# 416  /content/drive/MyDrive/DMS/data/YawDD dataset/...
# 417  /content/drive/MyDrive/DMS/data/YawDD dataset/...
# 418  /content/drive/MyDrive/DMS/data/YawDD dataset/...
#
#                                    filename  frame_count    fps
# 0        3-MaleNoGlasses-Yawning-clip-1.avi          180  29.97
# 1         11-MaleGlasses-Yawning-clip-0.avi          120  29.97
# 2         12-MaleGlasses-Yawning-clip-0.avi          120  29.97
# 3         12-MaleGlasses-Yawning-clip-2.avi          240  29.97
# 4         12-MaleGlasses-Yawning-clip-4.avi          121  29.97
# ..                                      ...          ...    ...
# 414   39-FemaleNoGlasses-Yawning-clip-0.avi           90  29.97
# 415     41-FemaleGlasses-Yawning-clip-0.avi           60  29.97
# 416   40-FemaleNoGlasses-Yawning-clip-1.avi          120  29.97
# 417  42-FemaleSunGlasses-Yawning-clip-1.avi           60  29.97
# 418   43-FemaleNoGlasses-Yawning-clip-1.avi           60  29.97
#
# [419 rows x 4 columns]

# %%
df["fps"].unique()
# Out:
# array([29.97, 30.  ])

# %% [markdown]
# # DMD 클립 영상별 총 프레임 수와 FPS

# %%
dmd_data_path = "/content/drive/MyDrive/DMS/data/DMD/dmd-clip"
df_dmd_total = analyze_videos_with_fps(dmd_data_path)

df_dmd_total
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-c75bebefc622> in <cell line: 0>()
#       1 dmd_data_path = "/content/drive/MyDrive/DMS/data/DMD/dmd-clip"
# ----> 2 df_dmd_total = analyze_videos_with_fps(dmd_data_path)
#       3
#       4 df_dmd_total
#
# <ipython-input-3-c6aa183406c7> in analyze_videos_with_fps(directory)
#      25             # 비디오 파일만 처리 (.mp4, .avi, .mov 등 추가 가능)
#      26             if filename.lower().endswith(('.mp4', '.avi', '.mov', '.mkv', '.flv', '.wmv')):
# ---> 27                 frame_count, fps = get_video_info(video_path)
#      28                 if frame_count is not None and fps is not None:
#      29                     video_data.append({
#
# <ipython-input-3-c6aa183406c7> in get_video_info(video_path)
#       5 def get_video_info(video_path):
#       6     """비디오 파일의 총 프레임 개수 및 FPS를 반환"""
# ----> 7     cap = cv2.VideoCapture(video_path)
#       8     if not cap.isOpened():
#       9         print(f"⚠️ 파일을 열 수 없음: {video_path}")
#
# KeyboardInterrupt:

# %%
import os
import cv2
import pandas as pd
from concurrent.futures import ThreadPoolExecutor  # 병렬 처리 추가

def get_video_info(video_path):
    """비디오 파일의 총 프레임 개수 및 FPS를 반환"""
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"⚠️ 파일을 열 수 없음: {video_path}")
        return None, None
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))  # 총 프레임 수
    fps = cap.get(cv2.CAP_PROP_FPS)  # FPS (초당 프레임 수)
    cap.release()
    return frame_count, round(fps, 2)

def analyze_videos_with_fps(directory):
    """디렉토리 및 하위 폴더 내 모든 비디오 파일의 프레임 개수와 FPS 계산 (병렬 처리)"""
    video_data = []

    # os.walk()를 사용하여 모든 하위 디렉토리 탐색
    video_files = []
    for root, _, files in os.walk(directory):
        for filename in files:
            if filename.lower().endswith(('.mp4', '.avi', '.mov', '.mkv', '.flv', '.wmv')):
                video_files.append((root, filename))

    # 병렬 처리 (멀티 스레딩)
    def process_video(file_info):
        root, filename = file_info
        video_path = os.path.join(root, filename)
        frame_count, fps = get_video_info(video_path)
        if frame_count is not None and fps is not None:
            return {"directory": root, "filename": filename, "frame_count": frame_count, "fps": fps}

    # 멀티 스레딩을 사용하여 비디오 처리 속도 개선
    with ThreadPoolExecutor(max_workers=8) as executor:  # 병렬로 8개 작업 실행
        results = list(executor.map(process_video, video_files))

    # None 값이 포함된 항목 제거
    video_data = [res for res in results if res is not None]

    # 데이터프레임 생성
    df = pd.DataFrame(video_data)
    return df

# 사용 예시 (Google Drive에서 실행할 경우)
dmd_data_path = "/content/drive/MyDrive/DMS/data/DMD/dmd-clip"
df_dmd_total = analyze_videos_with_fps(dmd_data_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-f064dc3874a6> in <cell line: 0>()
#      50
#      51 # 결과 출력
# ---> 52 import ace_tools as tools
#      53 tools.display_dataframe_to_user(name="Optimized Video FPS and Frame Counts", dataframe=df_dmd_total)
#
# ModuleNotFoundError: No module named 'ace_tools'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
df_dmd_total
# Out:
#                                               directory  \
# 0     /content/drive/MyDrive/DMS/data/DMD/dmd-clip/g...
# 1     /content/drive/MyDrive/DMS/data/DMD/dmd-clip/g...
# 2     /content/drive/MyDrive/DMS/data/DMD/dmd-clip/g...
# 3     /content/drive/MyDrive/DMS/data/DMD/dmd-clip/g...
# 4     /content/drive/MyDrive/DMS/data/DMD/dmd-clip/g...
# ...                                                 ...
# 3611  /content/drive/MyDrive/DMS/data/DMD/dmd-clip/g...
# 3612  /content/drive/MyDrive/DMS/data/DMD/dmd-clip/g...
# 3613  /content/drive/MyDrive/DMS/data/DMD/dmd-clip/g...
# 3614  /content/drive/MyDrive/DMS/data/DMD/dmd-clip/g...
# 3615  /content/drive/MyDrive/DMS/data/DMD/dmd-clip/g...
#
#                                filename  frame_count    fps
# 0      body_2019-03-14-14;31;08_1_0.avi           74  29.76
# 1      body_2019-03-14-14;31;08_1_1.avi          550  29.76
# 2      body_2019-03-14-14;31;08_1_2.avi          335  29.76
# 3      body_2019-03-14-14;31;08_1_3.avi          354  29.76
# 4      face_2019-03-14-14;31;08_1_0.avi           74  29.76
# ...                                 ...          ...    ...
# 3611  face_2019-04-02-10;01;53_34_2.avi          166  29.76
# 3612  body_2019-04-03-09;47;42_34_0.avi          578  29.76
# 3613  body_2019-04-03-09;47;42_34_1.avi          732  29.76
# 3614  face_2019-04-03-09;47;42_34_0.avi          578  29.76
# 3615  face_2019-04-03-09;47;42_34_1.avi          732  29.76
#
# [3616 rows x 4 columns]

# %%
df_dmd_total["fps"].unique()
# Out:
# array([29.76])

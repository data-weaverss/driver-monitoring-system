# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %% [markdown]
# ## **학습 & 테스트 프로세스 요약**
# | 단계 | 학습 (Train) | 테스트 (Test) |
# |------|------------|-------------|
# | **1. 데이터 입력** | CSV 파일 (이미 추출된 특징값) | 동영상 |
# | **2. 특징 추출** | CSV에서 불러오기 | 동영상 → 프레임 추출 → 12개 묶음 → 특징 추출 |
# | **3. 데이터 변환** | `(배치, 12, 5)` 형태로 변환 | `(1, 12, 5)` 형태로 변환 |
# | **4. 모델 학습/예측** | LSTM 모델 학습 | LSTM 모델을 이용해 예측 |
# | **5. 결과 저장** | `.pth` 파일로 저장 | 예측값 출력 |

# %% [markdown]
# # 1. 학습

# %% [markdown]
# 1. 추출된 feature 로드 및 병합
# 2. LSTM Input 형식으로 변환
# 3. LSTM 학습

# %% [markdown]
# ## 라이브러리 임포트

# %%
# !pip install koreanize-matplotlib

# %%
import os
import datetime
from tqdm import tqdm
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter
import koreanize_matplotlib

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, TensorDataset
import torch.utils.data as data
import torch.optim as optim
import torchvision
from torch.autograd import Variable

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from PIL import Image

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1-2. LSTM Input 형식으로 변환

# %% [markdown]
# ### Config 설정

# %%
config = {
    # RNN 설정
    "RNN_hidden_layers": 3,  # LSTM Layer 개수
    "RNN_hidden_nodes": 512,  # RNN Hidden State 크기
    "RNN_FC_dim": 256,  # RNN 최종 FC Layer 뉴런 개수
    "dropout_p": 0.2,  # 드롭아웃 비율

    # 학습 설정
    "k": 4,  # 클래스 개수 (normal, yawn, phonecall, text)
    "feature_num": 5, # Pitch, Yaw, EAR, MAR, Phone Detected
    "timestep": 24,
    "sliding_step": 12,
    "epochs": 100,  # 총 학습 횟수
    "batch_size": 32,  # 배치 크기
    "learning_rate": 5e-5,  # 학습률
    "log_interval": 5,  # 몇 번의 배치마다 로그 출력할지

    "action_names": ["normal", "yawn", "phonecall", "text"],  # 분류할 행동 리스트

    "use_cuda": torch.cuda.is_available(),
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),  # GPU 사용 가능 여부에 따라 설정
    "early_stopping_patience": 50,  # Early Stopping 기준 Epoch
    "reduce_lr_factor": 0.5,  # Learning Rate 감소 비율
    "reduce_lr_patience": 3,  # Learning Rate 감소 기준 Epoch

    # 모델 결과 저장 경로
    "model_save_path": "/content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding",
    "train_result_path": "/content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results",
}

# %% [markdown]
# ## 데이터 로드

# %% [markdown]
# ### label encoder

# %%
# 하이퍼파라미터
BATCH_SIZE = config['batch_size']
TIMESTEP = config['timestep']
FEATURE_DIM = config['feature_num'] # Pitch, Yaw, EAR, MAR, Phone Detected
NUM_CLASSES = config['k']  # normal, phonecall, text, yawn
SLIDING_STEP = config['sliding_step']

# 공통 로직: 데이터프레임 처리 및 시퀀스 생성
def process_features(df, sliding_labels=None, is_train=True):
    """
    데이터프레임에서 시퀀스를 생성하는 함수.

    Args:
        df (pd.DataFrame): 입력 데이터프레임.
        sliding_labels (list): Sliding window 방식 적용할 라벨 리스트 (예: ['text', 'yawn']).
        is_train (bool): 학습용 데이터 여부. 테스트 데이터는 sliding step을 사용하지 않음.

    Returns:
        torch.Tensor: 시퀀스 데이터.
        torch.Tensor: 라벨 데이터.
        list: 메타데이터 (label, group_key, sequence_index).
    """
    # 같은 클립끼리 묶을 group_key 생성
    df['group_key'] = df['video_name'].apply(lambda x: "_".join(x.split("_")[:-1]))

    # label 인코딩
    label_mapping = {"normal": 0, "phonecall": 1, "text": 2, "yawn": 3}
    df['label_encoded'] = df['label'].map(label_mapping)

    sequences = []
    labels = []
    metadata = []  # 메타데이터 저장 리스트

    for (label, group_key), group in df.groupby(['label', 'group_key']):
        group = group.sort_values(by='frame')  # 프레임 순서대로 정렬
        features = group[['gaze_yaw', 'gaze_pitch', 'MAR', 'EAR', 'phone_detected']].values
        label_encoded = group['label_encoded'].iloc[0]  # 해당 비디오의 라벨 (모든 프레임 동일)

        # Sliding window 방식 적용 여부 결정
        if is_train and sliding_labels and label in sliding_labels:
            step_size = SLIDING_STEP
        else:
            step_size = TIMESTEP

        for start_idx in range(0, len(features) - TIMESTEP + 1, step_size):
            end_idx = start_idx + TIMESTEP
            if end_idx <= len(features):  # 마지막 시퀀스가 seq_length에 맞는 경우만 처리
                sequences.append(features[start_idx:end_idx])
                labels.append(label_encoded)
                metadata.append((label, group_key, start_idx))  # 메타데이터 추가

    # pytorch tensor 변환
    return (torch.tensor(sequences, dtype=torch.float32), torch.tensor(labels, dtype=torch.float32), metadata)


# 학습용 데이터 로드 함수
def load_train_features(df):
    """
    학습용 데이터를 처리하여 시퀀스를 생성하는 함수.
    """
    sliding_labels = ['text', 'yawn']  # Sliding window 방식 적용할 라벨 리스트
    return process_features(df, sliding_labels=sliding_labels, is_train=True)

# 테스트용 데이터 로드 함수
def load_test_features(df):
    """
    테스트용 데이터를 처리하여 시퀀스를 생성하는 함수.
    """
    return process_features(df, sliding_labels=None, is_train=False)

# %%
required_cols = ['label', 'video_name', 'frame']
feature_cols = ["gaze_pitch", "gaze_yaw", "EAR", "MAR", "phone_detected"]

train = pd.read_csv("/content/drive/MyDrive/DMS/data/EDA/train_processed.csv")
test = pd.read_csv("/content/drive/MyDrive/DMS/data/EDA/test_processed.csv")

train = train[required_cols + feature_cols]
test = test[required_cols + feature_cols]

# %% [markdown]
# ### train에서 normal 1, 2 만 선택

# %%
print(f"before filtering normal: {len(train)}")
train = train[
    ((train['label'] == 'normal') &
     ((train['video_name'].str.split('_').str[-1] == 'part1') |
      (train['video_name'].str.split('_').str[-1] == 'part2'))) |
    (train['label'] != 'normal')
]
display(train.head())
print(f"after filtering normal: {len(train)}")
# Out:
# before filtering normal: 104940
#     label                                         video_name            frame  \
# 0  normal  gB-10(File10)_s1_face_2019-03-11-15_24_54_10_0...  frame000000.jpg
# 1  normal  gB-10(File10)_s1_face_2019-03-11-15_24_54_10_0...  frame000001.jpg
# 2  normal  gB-10(File10)_s1_face_2019-03-11-15_24_54_10_0...  frame000002.jpg
# 3  normal  gB-10(File10)_s1_face_2019-03-11-15_24_54_10_0...  frame000003.jpg
# 4  normal  gB-10(File10)_s1_face_2019-03-11-15_24_54_10_0...  frame000004.jpg
#
#    gaze_pitch  gaze_yaw       EAR       MAR  phone_detected
# 0   -0.802380 -0.178544  0.188577  0.152621               0
# 1   -0.258022 -0.444779  0.115461  0.098821               0
# 2    0.173530 -0.746606  0.101308  0.080448               0
# 3   -0.022168 -0.725515  0.101270  0.099019               0
# 4   -0.187156 -0.672688  0.110530  0.118148               0
# after filtering normal: 71592

# %%
train.dropna(inplace=True)
test.dropna(inplace=True)
print("학습 데이터: ", train.shape)
print("테스트 데이터: ", test.shape)
# Out:
# 학습 데이터:  (71520, 8)
# 테스트 데이터:  (23544, 8)

# %%
train_count = train.groupby('label')['label'].count().reset_index(name='frame_count')
train_count['clip_count'] = train_count['frame_count'] // 12
train_count['ratio'] = round(train_count['clip_count'] / train_count['clip_count'].sum() * 100, 1) # 비율 계산
print("-----------Train-----------")
display(train_count)
print("-----------Test-----------")
test_count = test.groupby('label')['label'].count().reset_index(name='frame_count')
test_count['clip_count'] = test_count['frame_count'] // 12
test_count['ratio'] = round(test_count['clip_count'] / test_count['clip_count'].sum() * 100, 1) # 비율 계산
display(test_count)
# Out:
# -----------Train-----------
#        label  frame_count  clip_count  ratio
# 0     normal        31800        2650   44.5
# 1  phonecall        25272        2106   35.3
# 2       text        10044         837   14.0
# 3       yawn         4404         367    6.2
# -----------Test-----------
#        label  frame_count  clip_count  ratio
# 0     normal        14100        1175   59.9
# 1  phonecall         5664         472   24.1
# 2       text         2568         214   10.9
# 3       yawn         1212         101    5.1

# %%
# Train, Test dataset
train_features, train_labels, train_meta = load_train_features(train)
test_features, test_labels, test_meta = load_test_features(test)

# %%
label_mapping_inverse = {
    0: "normal",
    1: "phonecall",
    2: "text",
    3: "yawn"
}

# 레이블 개수 및 비율 계산
label_counts = pd.Series(train_labels).value_counts()
label_ratios = pd.Series(train_labels).value_counts(normalize=True) * 100  # 비율 계산 (백분율)

# 매핑된 결과 출력
print("레이블 분포:")
print("-----------Train-----------")
for label, count in label_counts.items():
    print(f"{label_mapping_inverse[label]}: {count}개 ({label_ratios[label]:.2f}%)")

# 레이블 개수 및 비율 계산
label_counts = pd.Series(test_labels).value_counts()
label_ratios = pd.Series(test_labels).value_counts(normalize=True) * 100  # 비율 계산 (백분율)

print("-----------Test-----------")
for label, count in label_counts.items():
    print(f"{label_mapping_inverse[label]}: {count}개 ({label_ratios[label]:.2f}%)")
# Out:
# 레이블 분포:
# -----------Train-----------
# normal: 1129개 (36.76%)
# phonecall: 1015개 (33.05%)
# text: 712개 (23.18%)
# yawn: 215개 (7.00%)
# -----------Test-----------
# normal: 493개 (57.59%)
# phonecall: 229개 (26.75%)
# text: 96개 (11.21%)
# yawn: 38개 (4.44%)

# %% [markdown]
# ### 데이터 둘러보기 - 시각화
# - 훈련 데이터 개수
# - 테스트 데이터 개수
# - 타겟값 분포

# %%
def visualize_data_distribution(train_labels, test_labels, label_mapping_inverse):
    """
    훈련/테스트 데이터의 레이블 분포를 시각화하는 함수.

    Args:
        train_labels (list or pd.Series): 훈련 데이터의 레이블.
        test_labels (list or pd.Series): 테스트 데이터의 레이블.
        label_mapping_inverse (dict): 정수형 레이블을 문자열로 매핑하는 딕셔너리.
    """
    # 레이블 개수 및 비율 계산
    train_label_counts = pd.Series(train_labels).value_counts()
    train_label_ratios = pd.Series(train_labels).value_counts(normalize=True) * 100

    test_label_counts = pd.Series(test_labels).value_counts()
    test_label_ratios = pd.Series(test_labels).value_counts(normalize=True) * 100

    # 클래스 이름 매핑
    class_names = [label_mapping_inverse[label] for label in train_label_counts.index]

    # 시각화
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))

    # (왼쪽) Bar Chart - 클래스별 샘플 개수 비교
    x = np.arange(len(class_names))
    width = 0.4

    axes[0].bar(x - width / 2, train_label_counts.values, width, label="Train", alpha=0.7)
    axes[0].bar(x + width / 2, test_label_counts.values, width, label="Test", alpha=0.7)
    axes[0].set_xticks(x)
    axes[0].set_xticklabels(class_names, rotation=45)
    axes[0].set_ylabel("샘플 개수")
    axes[0].set_title("클래스별 데이터 분포")
    axes[0].legend()

    # (오른쪽) Pie Chart - 전체 데이터 비율
    total_counts = train_label_counts + test_label_counts
    total_ratios = total_counts / total_counts.sum() * 100

    axes[1].pie(
        total_counts,
        labels=[f"{class_names[i]} ({total_ratios[i]:.1f}%)" for i in range(len(class_names))],
        autopct="%1.1f%%",
        startangle=140,
        colors=plt.cm.Paired.colors,
    )
    axes[1].set_title("클래스별 전체 데이터 비율")

    plt.tight_layout()
    plt.show()

visualize_data_distribution(train_labels, test_labels, label_mapping_inverse)

# %% [markdown]
# ### DataLoader

# %%
# DataLoader 설정
params = {
    "batch_size": config["batch_size"],
    "shuffle": True,
    "num_workers": 4,
    "pin_memory": True,
    "persistent_workers": True,
    "prefetch_factor": 2,
} if config["use_cuda"] else {}

# %%
# DataLoader 생성 (배치 단위로 데이터를 나누기 위해 사용)
train_dataset = TensorDataset(train_features, train_labels)
test_dataset = TensorDataset(test_features, test_labels)

train_loader = DataLoader(train_dataset, **params)
test_loader = DataLoader(test_dataset, **params)

# 배치 단위 확인
for x_batch, y_batch in train_loader:
    print("Batch Shape:", x_batch.shape, y_batch.shape)  # (batch_size, timestep, feature), (batch_size,)
    break  # 한 배치만 확인

for x_batch, y_batch in test_loader:
    print("Batch Shape:", x_batch.shape, y_batch.shape)  # (batch_size, timestep, feature), (batch_size,)
    break  # 한 배치만 확인
# Out:
# Batch Shape: torch.Size([32, 24, 5]) torch.Size([32])
# Batch Shape: torch.Size([32, 24, 5]) torch.Size([32])

# %%
# Train, Test 라벨별 개수 확인
labels = train_labels.to(torch.long)#  Long 타입으로 변환
counts = torch.bincount(labels)
print(counts)

labels = test_labels.to(torch.long)
counts = torch.bincount(labels)
print(counts)
# Out:
# tensor([1129, 1015,  712,  215])
# tensor([493, 229,  96,  38])

# %% [markdown]
# ## 1-3. LSTM 학습

# %%
# LSTM 모델 정의
class DecoderRNN(nn.Module):
    def __init__(self, config):
        super(DecoderRNN, self).__init__()

        self.RNN_input_size = config['feature_num']  # 특징 개수
        self.h_RNN_layers = config["RNN_hidden_layers"]
        self.h_RNN = config["RNN_hidden_nodes"]
        self.h_FC_dim = config["RNN_FC_dim"]
        self.drop_p = config["dropout_p"]
        self.num_classes = config["k"]

        self.LSTM = nn.LSTM(
            input_size=self.RNN_input_size,
            hidden_size=self.h_RNN,
            num_layers=self.h_RNN_layers,
            batch_first=True,
        )

        self.fc1 = nn.Linear(self.h_RNN, self.h_FC_dim)
        self.fc2 = nn.Linear(self.h_FC_dim, self.num_classes)
        self.dropout = nn.Dropout(p=self.drop_p)

    def forward(self, x_RNN):
        self.LSTM.flatten_parameters()
        RNN_out, _ = self.LSTM(x_RNN, None)

        # FC layers
        x = self.fc1(RNN_out[:, -1, :])  # 마지막 타임스텝a 사용
        x = F.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)

        return x  # CrossEntropyLoss 사용 (Softmax 없음)

# %% [markdown]
# ### optimizer

# %%
def get_optimizer(model, config):
    return optim.Adam(model.parameters(), lr=config["learning_rate"])
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ### 학습률 감소 스케줄러 설정
# Test Loss 기준
# - factor: 0.5, 학습률 50% 감소
# - verbose: True, 감소된 경우 로그 출력

# %%
def get_scheduler(optimizer, config):
    return optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode="min",
        factor=config["reduce_lr_factor"],
        patience=config["reduce_lr_patience"],
    )

# %% [markdown]
# ### Early Stopping 설정

# %%
early_stopping_patience = config["early_stopping_patience"]
best_loss = np.inf
patience_counter = 0

# %% [markdown]
# ## 학습 진행

# %% [markdown]
# - Mixed Precision Training 유지 (torch.cuda.amp.autocast() + GradScaler())
# -  Gradient Clipping 추가 (torch.nn.utils.clip_grad_norm_()) → 폭발적인 기울기(Gradient Explosion) 방지
# - 모델 저장 기능 추가 (torch.save()) → Best Loss 갱신 시 자동 저장
# - 학습률 스케줄러 로깅 추가 → ReduceLROnPlateau가 작동했는지 확인 가능

# %%
def save_best_model(model, optimizer, epoch, best_loss, save_path):
    """Validation Loss가 가장 낮을 때만 모델을 저장하는 함수"""
    today_date = datetime.datetime.now().strftime("%Y-%m-%d")  # 날짜 가져오기
    model_filename = f"{save_path}/best_model_{today_date}.pth"  # 저장 파일명

    # 기존 최적 모델 삭제 (이전 모델 유지 안 함)
    if os.path.exists(model_filename):
        os.remove(model_filename)

    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'best_loss': best_loss
    }, model_filename)

    print(f"💾 Best Model Updated! Saved at {model_filename} (Loss: {best_loss:.4f})")

def save_training_results(
        epoch_train_losses,
        epoch_train_scores,
        epoch_test_losses,
        epoch_test_scores,
        save_path="./",
        ):
    """
    학습 과정의 손실(loss)과 정확도(score)를 저장하는 함수
    """
    os.makedirs(save_path, exist_ok=True)

    np.save(
        os.path.join(save_path, "LSTM_epoch_training_losses.npy"),
        np.array(epoch_train_losses),
    )
    np.save(
        os.path.join(save_path, "LSTM_epoch_tsave_path, raining_scores.npy"),
        np.array(epoch_train_scores),
    )
    np.save(
        os.path.join(save_path, "LSTM_epoch_test_loss.npy"), np.array(epoch_test_losses)
    )
    np.save(
        os.path.join(save_path, "LSTM_epoch_test_score.npy"),
        np.array(epoch_test_scores),
    )

# %% [markdown]
# ### epoch마다 train data로 성능평가
# - 다음 기술을 적용하는 기준: Train data Loss
#     - Early Stopping
#     - 학습률 감소 스케줄러
#     - 모델 저장 (Best Loss 갱신 시)

# %%
# Mixed Precision Training을 위한 GradScaler 설정
scaler = torch.amp.GradScaler()

def train_model(model, train_loader, optimizer, criterion, scheduler, config):
    """
    Mixed Precision Training & Early Stopping 적용 학습 함수
    """
    model.to(config["device"])

    best_loss = np.inf  # Best Loss 초기화
    patience_counter = 0  # Early Stopping 카운터
    epoch_losses, epoch_scores = [], []  # Loss 및 Accuracy 저장용 리스트

    for epoch in range(config["epochs"]):
        model.train()
        losses, scores = [], []
        total_samples = 0

        # tqdm을 사용하여 학습 진행률 표시
        progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{config['epochs']}", leave=True)

        for batch_idx, (X, y) in enumerate(progress_bar):
            X, y = X.to(config["device"]), y.to(config["device"]).long()

            # Mixed Precision Training 적용
            total_samples += X.size(0)
            optimizer.zero_grad(set_to_none=True)

            with torch.amp.autocast('cuda'): # 자동 Mixed Precision 사용
                output = model(X)  # LSTM 모델 Forward Pass
                loss = criterion(output, y)

            scaler.scale(loss).backward()  # Mixed Precision Backpropagation
            scaler.step(optimizer)  # 옵티마이저 업데이트
            scaler.update()  # Scaler 업데이트

            losses.append(loss.item())

            # 정확도 계산
            y_pred = torch.argmax(output, dim=1)
            acc = accuracy_score(y.cpu().numpy(), y_pred.cpu().numpy())
            scores.append(acc)

        avg_loss = sum(losses) / len(losses)
        avg_acc = sum(scores) / len(scores) * 100

        print(f"✅ Epoch {epoch+1} Finished - Avg Loss: {avg_loss:.4f}, Avg Acc: {avg_acc:.2f}%")

        # Loss 및 Accuracy 저장
        epoch_losses.append(avg_loss)
        epoch_scores.append(avg_acc)

        # 학습률 감소 스케줄러 업데이트 (`ReduceLROnPlateau` 사용 시 `min` 모드 적용)
        scheduler.step(avg_loss)
        if optimizer.param_groups[0]["lr"] != config["learning_rate"]:
            print(f"📉 Learning Rate Reduced: {optimizer.param_groups[0]['lr']:.6e}")

        # 모델 저장 (Best Loss 갱신 시)
        if avg_loss < best_loss:
            best_loss = avg_loss
            patience_counter = 0  # Early Stopping Counter 초기화
            save_best_model(model, optimizer, epoch, best_loss, config["model_save_path"])
            print(f"💾 Model Saved! New Best Loss: {best_loss:.4f}")
        else:
            patience_counter += 1

        # Early Stopping 체크
        if patience_counter >= config["early_stopping_patience"]:
            print(f"🚨 Early Stopping Triggered! Best Loss: {best_loss:.4f}")
            break

    return epoch_losses, epoch_scores

# %%
def ensure_directory_exists(path):
    """주어진 경로의 폴더가 없으면 생성하는 함수"""
    if not os.path.exists(path):
        os.makedirs(path)
        print(f"📂 Directory created: {path}")

# %%
# ✅ 경로 자동 생성 (존재하지 않으면 생성)
ensure_directory_exists(os.path.dirname(config["model_save_path"]))  # 모델 저장 폴더
ensure_directory_exists(config["train_result_path"])  # 학습 결과 폴더

# %%
# device = config["device"]

# model = DecoderRNN(config)
# model.to(device)  # 모델을 GPU로 이동

# optimizer = get_optimizer(model, config)
# scheduler = get_scheduler(optimizer, config)

# epoch_losses, epoch_scores = train_model(model, train_loader, optimizer, criterion, scheduler, config)

# %% [markdown]
# ### epoch마다 test data로 성능평가
# - 다음 기술을 적용하는 기준: Test data Loss
#     - Early Stopping
#     - 학습률 감소 스케줄러
#     - 모델 저장 (Best Loss 갱신 시)

# %%
# Mixed Precision Training을 위한 GradScaler 설정
scaler = torch.amp.GradScaler()

# 학습 결과 저장 함수
def save_training_results(epoch, train_losses, train_scores, test_losses, test_scores, save_path):
    """학습 결과를 CSV 파일로 저장하는 함수"""
    results_df = pd.DataFrame({
        "epoch": list(range(1, epoch + 2)),
        "train_loss": train_losses,
        "train_accuracy": train_scores,
        "test_loss": test_losses,
        "test_accuracy": test_scores,
    })

    results_df.to_csv(f"{save_path}/training_results.csv", index=False)
    print(f"💾 Training results saved at {save_path}/training_results.csv")

# 학습 함수
def train(log_interval, model, device, train_loader, optimizer, criterion, epoch):
    model.train()
    losses, scores = [], []
    total_samples = 0

    # tqdm을 사용하여 학습 진행률 표시
    progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{config['epochs']}", leave=True)

    for batch_idx, (X, y) in enumerate(progress_bar):
        X, y = X.to(device), y.to(device).long()
        total_samples += X.size(0)

        optimizer.zero_grad(set_to_none=True)

        with torch.amp.autocast(device_type='cuda'):
            output = model(X)
            loss = criterion(output, y)

        scaler.scale(loss).backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  #  Gradient Clipping
        scaler.step(optimizer)
        scaler.update()

        losses.append(loss.item())

        # 정확도 계산
        y_pred = torch.argmax(output, dim=1)
        acc = accuracy_score(y.cpu().numpy(), y_pred.cpu().numpy())
        scores.append(acc)

    avg_loss = sum(losses) / len(losses)
    avg_acc = sum(scores) / len(scores) * 100

    print(f"✅ Train Epoch {epoch+1} Finished - Avg Loss: {avg_loss:.4f}, Avg Acc: {avg_acc:.2f}%")

    return avg_loss, avg_acc  # 학습 Loss 및 Accuracy 반환

# 검증 함수
def validate(model, device, criterion, test_loader, epoch, model_save_path=None, optimizer=None):
    model.eval()
    losses, scores = [], []

    with torch.no_grad():
        for X, y in test_loader:
            X, y = X.to(device), y.to(device).long()

            with torch.amp.autocast(device_type='cuda'):
                output = model(X)
                loss = criterion(output, y)

            losses.append(loss.item())

            # 정확도 계산
            y_pred = torch.argmax(output, dim=1)
            acc = accuracy_score(y.cpu().numpy(), y_pred.cpu().numpy())
            scores.append(acc)

    avg_loss = sum(losses) / len(losses)
    avg_acc = sum(scores) / len(scores) * 100

    print(f"✅ Validation Finished - Avg Loss: {avg_loss:.4f}, Avg Acc: {avg_acc:.2f}%")
    # 모델 저장 기능(옵셔널)
    if model_save_path and optimizer:
        save_best_model(model, optimizer, epoch, best_loss, config["model_save_path"])

    return avg_loss, avg_acc  # 검증 Loss 및 Accuracy 반환

# %%
# 전체 학습 실행 코드
def train_and_validate(model, train_loader, test_loader, optimizer, criterion, scheduler, config):
    best_loss = np.inf  # Best Loss 초기화
    patience_counter = 0  # Early Stopping 카운터

    epoch_train_losses, epoch_train_scores = [], []
    epoch_test_losses, epoch_test_scores = [], []

    for epoch in range(config["epochs"]):
        # 학습 단계
        epoch_train_loss, epoch_train_score = train(
            config["log_interval"], model, config["device"], train_loader, optimizer, criterion, epoch
        )

        # 검증 단계
        epoch_test_loss, epoch_test_score = validate(
            model, config["device"], criterion, test_loader, epoch
        )

        # 결과 저장
        epoch_train_losses.append(epoch_train_loss)
        epoch_train_scores.append(epoch_train_score)
        epoch_test_losses.append(epoch_test_loss)
        epoch_test_scores.append(epoch_test_score)

        # 학습률 감소 적용
        scheduler.step(epoch_test_loss)

        # Early Stopping 체크
        if epoch_test_loss < best_loss:
            best_loss = epoch_test_loss
            patience_counter = 0  # 개선되었으므로 patience 초기화

            save_best_model(model, optimizer, epoch, best_loss, config["model_save_path"])
            print(f"💾 Model Saved! New Best Loss: {best_loss:.4f}")
        else:
            patience_counter += 1
            print(f"⏳ Early stopping 대기 카운트: {patience_counter}/{config['early_stopping_patience']}")

        # 설정된 patience 횟수만큼 개선되지 않으면 학습 중단
        if patience_counter >= config["early_stopping_patience"]:
            print("⏹️ Early stopping 적용됨. 학습 종료.")
            break  # 학습 중단

        # 학습 결과 저장
        save_training_results(
            epoch,
            epoch_train_losses,
            epoch_train_scores,
            epoch_test_losses,
            epoch_test_scores,
            save_path=config["train_result_path"],
        )

    return epoch_train_losses, epoch_train_scores, epoch_test_losses, epoch_test_scores

# %%
device = config["device"]

model = DecoderRNN(config)
model.to(device)  # 모델을 GPU로 이동

optimizer = get_optimizer(model, config)
scheduler = get_scheduler(optimizer, config)

epoch_train_losses, epoch_train_scores, epoch_test_losses, epoch_test_scores = train_and_validate(model, train_loader, test_loader, optimizer, criterion, scheduler, config)
# RuntimeError: DataLoader worker -> dataloader 재실행
# Out:
# Epoch 1/100: 100%|██████████| 96/96 [00:01<00:00, 78.23it/s]
# ✅ Train Epoch 1 Finished - Avg Loss: 1.3564, Avg Acc: 32.92%
# ✅ Validation Finished - Avg Loss: 1.3294, Avg Acc: 26.62%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 1.3294)
# 💾 Model Saved! New Best Loss: 1.3294
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 2/100: 100%|██████████| 96/96 [00:01<00:00, 79.29it/s]
# ✅ Train Epoch 2 Finished - Avg Loss: 1.3144, Avg Acc: 33.01%
# ✅ Validation Finished - Avg Loss: 1.2365, Avg Acc: 26.74%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 1.2365)
# 💾 Model Saved! New Best Loss: 1.2365
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 3/100: 100%|██████████| 96/96 [00:01<00:00, 79.62it/s]
# ✅ Train Epoch 3 Finished - Avg Loss: 1.2623, Avg Acc: 35.66%
# ✅ Validation Finished - Avg Loss: 1.1440, Avg Acc: 57.68%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 1.1440)
# 💾 Model Saved! New Best Loss: 1.1440
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 4/100: 100%|██████████| 96/96 [00:01<00:00, 78.29it/s]
# ✅ Train Epoch 4 Finished - Avg Loss: 1.2488, Avg Acc: 36.99%
# ✅ Validation Finished - Avg Loss: 1.1331, Avg Acc: 57.64%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 1.1331)
# 💾 Model Saved! New Best Loss: 1.1331
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 5/100: 100%|██████████| 96/96 [00:01<00:00, 76.31it/s]
# ✅ Train Epoch 5 Finished - Avg Loss: 1.2322, Avg Acc: 40.22%
# ✅ Validation Finished - Avg Loss: 1.1246, Avg Acc: 33.53%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 1.1246)
# 💾 Model Saved! New Best Loss: 1.1246
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 6/100: 100%|██████████| 96/96 [00:01<00:00, 51.32it/s]
# ✅ Train Epoch 6 Finished - Avg Loss: 1.1176, Avg Acc: 46.07%
# ✅ Validation Finished - Avg Loss: 0.9931, Avg Acc: 62.15%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.9931)
# 💾 Model Saved! New Best Loss: 0.9931
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 7/100: 100%|██████████| 96/96 [00:01<00:00, 62.37it/s]
# ✅ Train Epoch 7 Finished - Avg Loss: 0.9690, Avg Acc: 66.40%
# ✅ Validation Finished - Avg Loss: 0.8242, Avg Acc: 76.54%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.8242)
# 💾 Model Saved! New Best Loss: 0.8242
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 8/100: 100%|██████████| 96/96 [00:01<00:00, 80.19it/s]
# ✅ Train Epoch 8 Finished - Avg Loss: 0.8318, Avg Acc: 73.07%
# ✅ Validation Finished - Avg Loss: 0.6387, Avg Acc: 79.05%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.6387)
# 💾 Model Saved! New Best Loss: 0.6387
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 9/100: 100%|██████████| 96/96 [00:01<00:00, 81.09it/s]
# ✅ Train Epoch 9 Finished - Avg Loss: 0.7684, Avg Acc: 74.08%
# ✅ Validation Finished - Avg Loss: 0.6216, Avg Acc: 78.97%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.6216)
# 💾 Model Saved! New Best Loss: 0.6216
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 10/100: 100%|██████████| 96/96 [00:01<00:00, 79.52it/s]
# ✅ Train Epoch 10 Finished - Avg Loss: 0.7477, Avg Acc: 74.76%
# ✅ Validation Finished - Avg Loss: 0.6060, Avg Acc: 78.59%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.6060)
# 💾 Model Saved! New Best Loss: 0.6060
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 11/100: 100%|██████████| 96/96 [00:01<00:00, 78.93it/s]
# ✅ Train Epoch 11 Finished - Avg Loss: 0.7346, Avg Acc: 74.80%
# ✅ Validation Finished - Avg Loss: 0.6135, Avg Acc: 79.44%
# ⏳ Early stopping 대기 카운트: 1/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 12/100: 100%|██████████| 96/96 [00:01<00:00, 76.74it/s]
# ✅ Train Epoch 12 Finished - Avg Loss: 0.7249, Avg Acc: 75.35%
# ✅ Validation Finished - Avg Loss: 0.5820, Avg Acc: 81.83%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5820)
# 💾 Model Saved! New Best Loss: 0.5820
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 13/100: 100%|██████████| 96/96 [00:01<00:00, 75.13it/s]
# ✅ Train Epoch 13 Finished - Avg Loss: 0.7163, Avg Acc: 75.45%
# ✅ Validation Finished - Avg Loss: 0.5845, Avg Acc: 80.94%
# ⏳ Early stopping 대기 카운트: 1/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 14/100: 100%|██████████| 96/96 [00:01<00:00, 54.98it/s]
# ✅ Train Epoch 14 Finished - Avg Loss: 0.7092, Avg Acc: 75.58%
# ✅ Validation Finished - Avg Loss: 0.5722, Avg Acc: 82.45%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5722)
# 💾 Model Saved! New Best Loss: 0.5722
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 15/100: 100%|██████████| 96/96 [00:01<00:00, 57.83it/s]
# ✅ Train Epoch 15 Finished - Avg Loss: 0.7069, Avg Acc: 75.61%
# ✅ Validation Finished - Avg Loss: 0.5656, Avg Acc: 83.14%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5656)
# 💾 Model Saved! New Best Loss: 0.5656
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 16/100: 100%|██████████| 96/96 [00:01<00:00, 78.85it/s]
# ✅ Train Epoch 16 Finished - Avg Loss: 0.7054, Avg Acc: 75.48%
# ✅ Validation Finished - Avg Loss: 0.5911, Avg Acc: 81.79%
# ⏳ Early stopping 대기 카운트: 1/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 17/100: 100%|██████████| 96/96 [00:01<00:00, 77.92it/s]
# ✅ Train Epoch 17 Finished - Avg Loss: 0.6999, Avg Acc: 75.87%
# ✅ Validation Finished - Avg Loss: 0.5752, Avg Acc: 83.29%
# ⏳ Early stopping 대기 카운트: 2/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 18/100: 100%|██████████| 96/96 [00:01<00:00, 77.92it/s]
# ✅ Train Epoch 18 Finished - Avg Loss: 0.6975, Avg Acc: 76.20%
# ✅ Validation Finished - Avg Loss: 0.6182, Avg Acc: 79.78%
# ⏳ Early stopping 대기 카운트: 3/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 19/100: 100%|██████████| 96/96 [00:01<00:00, 79.52it/s]
# ✅ Train Epoch 19 Finished - Avg Loss: 0.6974, Avg Acc: 76.10%
# ✅ Validation Finished - Avg Loss: 0.5616, Avg Acc: 82.83%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5616)
# 💾 Model Saved! New Best Loss: 0.5616
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 20/100: 100%|██████████| 96/96 [00:01<00:00, 75.95it/s]
# ✅ Train Epoch 20 Finished - Avg Loss: 0.6968, Avg Acc: 75.87%
# ✅ Validation Finished - Avg Loss: 0.5722, Avg Acc: 82.83%
# ⏳ Early stopping 대기 카운트: 1/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 21/100: 100%|██████████| 96/96 [00:01<00:00, 77.62it/s]
# ✅ Train Epoch 21 Finished - Avg Loss: 0.6936, Avg Acc: 76.16%
# ✅ Validation Finished - Avg Loss: 0.5939, Avg Acc: 81.87%
# ⏳ Early stopping 대기 카운트: 2/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 22/100: 100%|██████████| 96/96 [00:01<00:00, 65.53it/s]
# ✅ Train Epoch 22 Finished - Avg Loss: 0.6871, Avg Acc: 76.36%
# ✅ Validation Finished - Avg Loss: 0.5872, Avg Acc: 82.14%
# ⏳ Early stopping 대기 카운트: 3/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 23/100: 100%|██████████| 96/96 [00:02<00:00, 45.28it/s]
# ✅ Train Epoch 23 Finished - Avg Loss: 0.6853, Avg Acc: 76.49%
# ✅ Validation Finished - Avg Loss: 0.5604, Avg Acc: 83.14%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5604)
# 💾 Model Saved! New Best Loss: 0.5604
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 24/100: 100%|██████████| 96/96 [00:01<00:00, 74.41it/s]
# ✅ Train Epoch 24 Finished - Avg Loss: 0.6878, Avg Acc: 76.56%
# ✅ Validation Finished - Avg Loss: 0.5711, Avg Acc: 83.26%
# ⏳ Early stopping 대기 카운트: 1/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 25/100: 100%|██████████| 96/96 [00:01<00:00, 79.13it/s]
# ✅ Train Epoch 25 Finished - Avg Loss: 0.6842, Avg Acc: 76.75%
# ✅ Validation Finished - Avg Loss: 0.5885, Avg Acc: 82.56%
# ⏳ Early stopping 대기 카운트: 2/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 26/100: 100%|██████████| 96/96 [00:01<00:00, 79.84it/s]
# ✅ Train Epoch 26 Finished - Avg Loss: 0.6841, Avg Acc: 76.78%
# ✅ Validation Finished - Avg Loss: 0.5607, Avg Acc: 82.87%
# ⏳ Early stopping 대기 카운트: 3/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 27/100: 100%|██████████| 96/96 [00:01<00:00, 77.35it/s]
# ✅ Train Epoch 27 Finished - Avg Loss: 0.6819, Avg Acc: 76.78%
# ✅ Validation Finished - Avg Loss: 0.5610, Avg Acc: 83.02%
# ⏳ Early stopping 대기 카운트: 4/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 28/100: 100%|██████████| 96/96 [00:01<00:00, 76.72it/s]
# ✅ Train Epoch 28 Finished - Avg Loss: 0.6748, Avg Acc: 76.98%
# ✅ Validation Finished - Avg Loss: 0.5746, Avg Acc: 82.99%
# ⏳ Early stopping 대기 카운트: 5/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 29/100: 100%|██████████| 96/96 [00:01<00:00, 75.13it/s]
# ✅ Train Epoch 29 Finished - Avg Loss: 0.6770, Avg Acc: 77.14%
# ✅ Validation Finished - Avg Loss: 0.5798, Avg Acc: 82.41%
# ⏳ Early stopping 대기 카운트: 6/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 30/100: 100%|██████████| 96/96 [00:01<00:00, 68.41it/s]
# ✅ Train Epoch 30 Finished - Avg Loss: 0.6780, Avg Acc: 76.75%
# ✅ Validation Finished - Avg Loss: 0.5682, Avg Acc: 82.75%
# ⏳ Early stopping 대기 카운트: 7/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 31/100: 100%|██████████| 96/96 [00:01<00:00, 53.79it/s]
# ✅ Train Epoch 31 Finished - Avg Loss: 0.6756, Avg Acc: 77.21%
# ✅ Validation Finished - Avg Loss: 0.5546, Avg Acc: 83.37%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5546)
# 💾 Model Saved! New Best Loss: 0.5546
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 32/100: 100%|██████████| 96/96 [00:01<00:00, 60.41it/s]
# ✅ Train Epoch 32 Finished - Avg Loss: 0.6751, Avg Acc: 77.20%
# ✅ Validation Finished - Avg Loss: 0.5587, Avg Acc: 83.37%
# ⏳ Early stopping 대기 카운트: 1/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 33/100: 100%|██████████| 96/96 [00:01<00:00, 78.82it/s]
# ✅ Train Epoch 33 Finished - Avg Loss: 0.6726, Avg Acc: 77.24%
# ✅ Validation Finished - Avg Loss: 0.5543, Avg Acc: 83.33%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5543)
# 💾 Model Saved! New Best Loss: 0.5543
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 34/100: 100%|██████████| 96/96 [00:01<00:00, 78.52it/s]
# ✅ Train Epoch 34 Finished - Avg Loss: 0.6725, Avg Acc: 77.01%
# ✅ Validation Finished - Avg Loss: 0.5639, Avg Acc: 83.37%
# ⏳ Early stopping 대기 카운트: 1/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 35/100: 100%|██████████| 96/96 [00:01<00:00, 76.04it/s]
# ✅ Train Epoch 35 Finished - Avg Loss: 0.6706, Avg Acc: 77.10%
# ✅ Validation Finished - Avg Loss: 0.5631, Avg Acc: 83.10%
# ⏳ Early stopping 대기 카운트: 2/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 36/100: 100%|██████████| 96/96 [00:01<00:00, 76.34it/s]
# ✅ Train Epoch 36 Finished - Avg Loss: 0.6645, Avg Acc: 77.34%
# ✅ Validation Finished - Avg Loss: 0.5560, Avg Acc: 83.56%
# ⏳ Early stopping 대기 카운트: 3/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 37/100: 100%|██████████| 96/96 [00:01<00:00, 78.21it/s]
# ✅ Train Epoch 37 Finished - Avg Loss: 0.6663, Avg Acc: 77.30%
# ✅ Validation Finished - Avg Loss: 0.5641, Avg Acc: 82.99%
# ⏳ Early stopping 대기 카운트: 4/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 38/100: 100%|██████████| 96/96 [00:01<00:00, 79.42it/s]
# ✅ Train Epoch 38 Finished - Avg Loss: 0.6654, Avg Acc: 77.40%
# ✅ Validation Finished - Avg Loss: 0.5538, Avg Acc: 83.53%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5538)
# 💾 Model Saved! New Best Loss: 0.5538
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 39/100: 100%|██████████| 96/96 [00:01<00:00, 65.49it/s]
# ✅ Train Epoch 39 Finished - Avg Loss: 0.6622, Avg Acc: 77.47%
# ✅ Validation Finished - Avg Loss: 0.5677, Avg Acc: 82.79%
# ⏳ Early stopping 대기 카운트: 1/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 40/100: 100%|██████████| 96/96 [00:01<00:00, 56.26it/s]
# ✅ Train Epoch 40 Finished - Avg Loss: 0.6601, Avg Acc: 77.20%
# ✅ Validation Finished - Avg Loss: 0.5576, Avg Acc: 83.49%
# ⏳ Early stopping 대기 카운트: 2/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 41/100: 100%|██████████| 96/96 [00:01<00:00, 72.67it/s]
# ✅ Train Epoch 41 Finished - Avg Loss: 0.6603, Avg Acc: 77.40%
# ✅ Validation Finished - Avg Loss: 0.5556, Avg Acc: 83.41%
# ⏳ Early stopping 대기 카운트: 3/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 42/100: 100%|██████████| 96/96 [00:01<00:00, 65.13it/s]
# ✅ Train Epoch 42 Finished - Avg Loss: 0.6573, Avg Acc: 77.37%
# ✅ Validation Finished - Avg Loss: 0.5502, Avg Acc: 83.64%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5502)
# 💾 Model Saved! New Best Loss: 0.5502
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 43/100: 100%|██████████| 96/96 [00:01<00:00, 74.33it/s]
# ✅ Train Epoch 43 Finished - Avg Loss: 0.6576, Avg Acc: 77.53%
# ✅ Validation Finished - Avg Loss: 0.5498, Avg Acc: 83.60%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5498)
# 💾 Model Saved! New Best Loss: 0.5498
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 44/100: 100%|██████████| 96/96 [00:01<00:00, 80.41it/s]
# ✅ Train Epoch 44 Finished - Avg Loss: 0.6553, Avg Acc: 77.63%
# ✅ Validation Finished - Avg Loss: 0.5470, Avg Acc: 83.29%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5470)
# 💾 Model Saved! New Best Loss: 0.5470
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 45/100: 100%|██████████| 96/96 [00:01<00:00, 80.92it/s]
# ✅ Train Epoch 45 Finished - Avg Loss: 0.6539, Avg Acc: 77.50%
# ✅ Validation Finished - Avg Loss: 0.5478, Avg Acc: 83.37%
# ⏳ Early stopping 대기 카운트: 1/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 46/100: 100%|██████████| 96/96 [00:01<00:00, 80.82it/s]
# ✅ Train Epoch 46 Finished - Avg Loss: 0.6504, Avg Acc: 77.86%
# ✅ Validation Finished - Avg Loss: 0.5508, Avg Acc: 83.37%
# ⏳ Early stopping 대기 카운트: 2/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 47/100: 100%|██████████| 96/96 [00:01<00:00, 82.49it/s]
# ✅ Train Epoch 47 Finished - Avg Loss: 0.6505, Avg Acc: 77.69%
# ✅ Validation Finished - Avg Loss: 0.5418, Avg Acc: 83.45%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5418)
# 💾 Model Saved! New Best Loss: 0.5418
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 48/100: 100%|██████████| 96/96 [00:01<00:00, 56.96it/s]
# ✅ Train Epoch 48 Finished - Avg Loss: 0.6492, Avg Acc: 78.02%
# ✅ Validation Finished - Avg Loss: 0.5364, Avg Acc: 83.37%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5364)
# 💾 Model Saved! New Best Loss: 0.5364
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 49/100: 100%|██████████| 96/96 [00:01<00:00, 65.15it/s]
# ✅ Train Epoch 49 Finished - Avg Loss: 0.6432, Avg Acc: 78.11%
# ✅ Validation Finished - Avg Loss: 0.5367, Avg Acc: 83.64%
# ⏳ Early stopping 대기 카운트: 1/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 50/100: 100%|██████████| 96/96 [00:01<00:00, 76.27it/s]
# ✅ Train Epoch 50 Finished - Avg Loss: 0.6431, Avg Acc: 77.99%
# ✅ Validation Finished - Avg Loss: 0.5413, Avg Acc: 83.68%
# ⏳ Early stopping 대기 카운트: 2/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 51/100: 100%|██████████| 96/96 [00:01<00:00, 78.89it/s]
# ✅ Train Epoch 51 Finished - Avg Loss: 0.6426, Avg Acc: 78.02%
# ✅ Validation Finished - Avg Loss: 0.5400, Avg Acc: 83.87%
# ⏳ Early stopping 대기 카운트: 3/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 52/100: 100%|██████████| 96/96 [00:01<00:00, 81.98it/s]
# ✅ Train Epoch 52 Finished - Avg Loss: 0.6408, Avg Acc: 78.44%
# ✅ Validation Finished - Avg Loss: 0.5263, Avg Acc: 83.53%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5263)
# 💾 Model Saved! New Best Loss: 0.5263
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 53/100: 100%|██████████| 96/96 [00:01<00:00, 80.54it/s]
# ✅ Train Epoch 53 Finished - Avg Loss: 0.6383, Avg Acc: 78.48%
# ✅ Validation Finished - Avg Loss: 0.5235, Avg Acc: 83.45%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5235)
# 💾 Model Saved! New Best Loss: 0.5235
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 54/100: 100%|██████████| 96/96 [00:01<00:00, 81.29it/s]
# ✅ Train Epoch 54 Finished - Avg Loss: 0.6349, Avg Acc: 78.64%
# ✅ Validation Finished - Avg Loss: 0.5276, Avg Acc: 83.72%
# ⏳ Early stopping 대기 카운트: 1/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 55/100: 100%|██████████| 96/96 [00:01<00:00, 81.24it/s]
# ✅ Train Epoch 55 Finished - Avg Loss: 0.6347, Avg Acc: 78.83%
# ✅ Validation Finished - Avg Loss: 0.5279, Avg Acc: 83.87%
# ⏳ Early stopping 대기 카운트: 2/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 56/100: 100%|██████████| 96/96 [00:01<00:00, 67.26it/s]
# ✅ Train Epoch 56 Finished - Avg Loss: 0.6343, Avg Acc: 78.74%
# ✅ Validation Finished - Avg Loss: 0.5205, Avg Acc: 83.80%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5205)
# 💾 Model Saved! New Best Loss: 0.5205
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 57/100: 100%|██████████| 96/96 [00:01<00:00, 49.14it/s]
# ✅ Train Epoch 57 Finished - Avg Loss: 0.6314, Avg Acc: 78.77%
# ✅ Validation Finished - Avg Loss: 0.5245, Avg Acc: 84.03%
# ⏳ Early stopping 대기 카운트: 1/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 58/100: 100%|██████████| 96/96 [00:01<00:00, 78.90it/s]
# ✅ Train Epoch 58 Finished - Avg Loss: 0.6286, Avg Acc: 79.03%
# ✅ Validation Finished - Avg Loss: 0.5279, Avg Acc: 83.99%
# ⏳ Early stopping 대기 카운트: 2/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 59/100: 100%|██████████| 96/96 [00:01<00:00, 81.16it/s]
# ✅ Train Epoch 59 Finished - Avg Loss: 0.6286, Avg Acc: 79.13%
# ✅ Validation Finished - Avg Loss: 0.5236, Avg Acc: 84.14%
# ⏳ Early stopping 대기 카운트: 3/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 60/100: 100%|██████████| 96/96 [00:01<00:00, 78.54it/s]
# ✅ Train Epoch 60 Finished - Avg Loss: 0.6259, Avg Acc: 79.16%
# ✅ Validation Finished - Avg Loss: 0.5251, Avg Acc: 83.95%
# ⏳ Early stopping 대기 카운트: 4/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 61/100: 100%|██████████| 96/96 [00:01<00:00, 71.00it/s]
# ✅ Train Epoch 61 Finished - Avg Loss: 0.6266, Avg Acc: 79.09%
# ✅ Validation Finished - Avg Loss: 0.5300, Avg Acc: 84.14%
# ⏳ Early stopping 대기 카운트: 5/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 62/100: 100%|██████████| 96/96 [00:01<00:00, 77.26it/s]
# ✅ Train Epoch 62 Finished - Avg Loss: 0.6241, Avg Acc: 79.29%
# ✅ Validation Finished - Avg Loss: 0.5269, Avg Acc: 83.91%
# ⏳ Early stopping 대기 카운트: 6/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 63/100: 100%|██████████| 96/96 [00:01<00:00, 79.59it/s]
# ✅ Train Epoch 63 Finished - Avg Loss: 0.6239, Avg Acc: 79.23%
# ✅ Validation Finished - Avg Loss: 0.5316, Avg Acc: 84.14%
# ⏳ Early stopping 대기 카운트: 7/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 64/100: 100%|██████████| 96/96 [00:01<00:00, 79.35it/s]
# ✅ Train Epoch 64 Finished - Avg Loss: 0.6226, Avg Acc: 79.13%
# ✅ Validation Finished - Avg Loss: 0.5279, Avg Acc: 84.14%
# ⏳ Early stopping 대기 카운트: 8/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 65/100: 100%|██████████| 96/96 [00:01<00:00, 56.80it/s]
# ✅ Train Epoch 65 Finished - Avg Loss: 0.6240, Avg Acc: 79.16%
# ✅ Validation Finished - Avg Loss: 0.5240, Avg Acc: 84.07%
# ⏳ Early stopping 대기 카운트: 9/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 66/100: 100%|██████████| 96/96 [00:01<00:00, 57.39it/s]
# ✅ Train Epoch 66 Finished - Avg Loss: 0.6228, Avg Acc: 79.23%
# ✅ Validation Finished - Avg Loss: 0.5251, Avg Acc: 83.91%
# ⏳ Early stopping 대기 카운트: 10/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 67/100: 100%|██████████| 96/96 [00:01<00:00, 80.52it/s]
# ✅ Train Epoch 67 Finished - Avg Loss: 0.6213, Avg Acc: 79.32%
# ✅ Validation Finished - Avg Loss: 0.5200, Avg Acc: 84.07%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5200)
# 💾 Model Saved! New Best Loss: 0.5200
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 68/100: 100%|██████████| 96/96 [00:01<00:00, 80.62it/s]
# ✅ Train Epoch 68 Finished - Avg Loss: 0.6239, Avg Acc: 79.36%
# ✅ Validation Finished - Avg Loss: 0.5194, Avg Acc: 84.10%
# 💾 Best Model Updated! Saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth (Loss: 0.5194)
# 💾 Model Saved! New Best Loss: 0.5194
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 69/100: 100%|██████████| 96/96 [00:01<00:00, 79.60it/s]
# ✅ Train Epoch 69 Finished - Avg Loss: 0.6232, Avg Acc: 79.26%
# ✅ Validation Finished - Avg Loss: 0.5202, Avg Acc: 84.10%
# ⏳ Early stopping 대기 카운트: 1/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 70/100: 100%|██████████| 96/96 [00:01<00:00, 80.51it/s]
# ✅ Train Epoch 70 Finished - Avg Loss: 0.6238, Avg Acc: 79.16%
# ✅ Validation Finished - Avg Loss: 0.5200, Avg Acc: 84.03%
# ⏳ Early stopping 대기 카운트: 2/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 71/100: 100%|██████████| 96/96 [00:01<00:00, 80.56it/s]
# ✅ Train Epoch 71 Finished - Avg Loss: 0.6222, Avg Acc: 79.33%
# ✅ Validation Finished - Avg Loss: 0.5234, Avg Acc: 84.07%
# ⏳ Early stopping 대기 카운트: 3/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 72/100: 100%|██████████| 96/96 [00:01<00:00, 80.20it/s]
# ✅ Train Epoch 72 Finished - Avg Loss: 0.6208, Avg Acc: 79.39%
# ✅ Validation Finished - Avg Loss: 0.5218, Avg Acc: 84.26%
# ⏳ Early stopping 대기 카운트: 4/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 73/100: 100%|██████████| 96/96 [00:01<00:00, 77.09it/s]
# ✅ Train Epoch 73 Finished - Avg Loss: 0.6240, Avg Acc: 79.29%
# ✅ Validation Finished - Avg Loss: 0.5231, Avg Acc: 84.26%
# ⏳ Early stopping 대기 카운트: 5/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 74/100: 100%|██████████| 96/96 [00:02<00:00, 46.21it/s]
# ✅ Train Epoch 74 Finished - Avg Loss: 0.6225, Avg Acc: 79.16%
# ✅ Validation Finished - Avg Loss: 0.5238, Avg Acc: 84.10%
# ⏳ Early stopping 대기 카운트: 6/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 75/100: 100%|██████████| 96/96 [00:01<00:00, 62.40it/s]
# ✅ Train Epoch 75 Finished - Avg Loss: 0.6227, Avg Acc: 79.28%
# ✅ Validation Finished - Avg Loss: 0.5211, Avg Acc: 84.30%
# ⏳ Early stopping 대기 카운트: 7/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 76/100: 100%|██████████| 96/96 [00:01<00:00, 80.70it/s]
# ✅ Train Epoch 76 Finished - Avg Loss: 0.6226, Avg Acc: 79.35%
# ✅ Validation Finished - Avg Loss: 0.5219, Avg Acc: 84.22%
# ⏳ Early stopping 대기 카운트: 8/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 77/100: 100%|██████████| 96/96 [00:01<00:00, 82.19it/s]
# ✅ Train Epoch 77 Finished - Avg Loss: 0.6235, Avg Acc: 79.26%
# ✅ Validation Finished - Avg Loss: 0.5222, Avg Acc: 84.26%
# ⏳ Early stopping 대기 카운트: 9/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 78/100: 100%|██████████| 96/96 [00:01<00:00, 82.67it/s]
# ✅ Train Epoch 78 Finished - Avg Loss: 0.6207, Avg Acc: 79.39%
# ✅ Validation Finished - Avg Loss: 0.5210, Avg Acc: 84.26%
# ⏳ Early stopping 대기 카운트: 10/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 79/100: 100%|██████████| 96/96 [00:01<00:00, 81.59it/s]
# ✅ Train Epoch 79 Finished - Avg Loss: 0.6188, Avg Acc: 79.26%
# ✅ Validation Finished - Avg Loss: 0.5216, Avg Acc: 84.26%
# ⏳ Early stopping 대기 카운트: 11/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 80/100: 100%|██████████| 96/96 [00:01<00:00, 80.73it/s]
# ✅ Train Epoch 80 Finished - Avg Loss: 0.6205, Avg Acc: 79.33%
# ✅ Validation Finished - Avg Loss: 0.5219, Avg Acc: 84.10%
# ⏳ Early stopping 대기 카운트: 12/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 81/100: 100%|██████████| 96/96 [00:01<00:00, 81.02it/s]
# ✅ Train Epoch 81 Finished - Avg Loss: 0.6221, Avg Acc: 79.25%
# ✅ Validation Finished - Avg Loss: 0.5212, Avg Acc: 84.22%
# ⏳ Early stopping 대기 카운트: 13/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 82/100: 100%|██████████| 96/96 [00:01<00:00, 75.51it/s]
# ✅ Train Epoch 82 Finished - Avg Loss: 0.6206, Avg Acc: 79.22%
# ✅ Validation Finished - Avg Loss: 0.5220, Avg Acc: 84.07%
# ⏳ Early stopping 대기 카운트: 14/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 83/100: 100%|██████████| 96/96 [00:01<00:00, 56.73it/s]
# ✅ Train Epoch 83 Finished - Avg Loss: 0.6191, Avg Acc: 79.29%
# ✅ Validation Finished - Avg Loss: 0.5232, Avg Acc: 84.10%
# ⏳ Early stopping 대기 카운트: 15/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 84/100: 100%|██████████| 96/96 [00:01<00:00, 59.84it/s]
# ✅ Train Epoch 84 Finished - Avg Loss: 0.6193, Avg Acc: 79.26%
# ✅ Validation Finished - Avg Loss: 0.5228, Avg Acc: 84.10%
# ⏳ Early stopping 대기 카운트: 16/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 85/100: 100%|██████████| 96/96 [00:01<00:00, 81.67it/s]
# ✅ Train Epoch 85 Finished - Avg Loss: 0.6197, Avg Acc: 79.45%
# ✅ Validation Finished - Avg Loss: 0.5215, Avg Acc: 84.18%
# ⏳ Early stopping 대기 카운트: 17/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 86/100: 100%|██████████| 96/96 [00:01<00:00, 82.73it/s]
# ✅ Train Epoch 86 Finished - Avg Loss: 0.6172, Avg Acc: 79.26%
# ✅ Validation Finished - Avg Loss: 0.5218, Avg Acc: 84.18%
# ⏳ Early stopping 대기 카운트: 18/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 87/100: 100%|██████████| 96/96 [00:01<00:00, 81.22it/s]
# ✅ Train Epoch 87 Finished - Avg Loss: 0.6216, Avg Acc: 79.19%
# ✅ Validation Finished - Avg Loss: 0.5219, Avg Acc: 84.14%
# ⏳ Early stopping 대기 카운트: 19/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 88/100: 100%|██████████| 96/96 [00:01<00:00, 82.00it/s]
# ✅ Train Epoch 88 Finished - Avg Loss: 0.6212, Avg Acc: 79.35%
# ✅ Validation Finished - Avg Loss: 0.5213, Avg Acc: 84.14%
# ⏳ Early stopping 대기 카운트: 20/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 89/100: 100%|██████████| 96/96 [00:01<00:00, 80.96it/s]
# ✅ Train Epoch 89 Finished - Avg Loss: 0.6199, Avg Acc: 79.46%
# ✅ Validation Finished - Avg Loss: 0.5227, Avg Acc: 84.07%
# ⏳ Early stopping 대기 카운트: 21/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 90/100: 100%|██████████| 96/96 [00:01<00:00, 78.61it/s]
# ✅ Train Epoch 90 Finished - Avg Loss: 0.6215, Avg Acc: 79.39%
# ✅ Validation Finished - Avg Loss: 0.5225, Avg Acc: 84.07%
# ⏳ Early stopping 대기 카운트: 22/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 91/100: 100%|██████████| 96/96 [00:02<00:00, 40.51it/s]
# ✅ Train Epoch 91 Finished - Avg Loss: 0.6195, Avg Acc: 79.29%
# ✅ Validation Finished - Avg Loss: 0.5215, Avg Acc: 84.14%
# ⏳ Early stopping 대기 카운트: 23/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 92/100: 100%|██████████| 96/96 [00:01<00:00, 56.38it/s]
# ✅ Train Epoch 92 Finished - Avg Loss: 0.6208, Avg Acc: 79.33%
# ✅ Validation Finished - Avg Loss: 0.5222, Avg Acc: 84.10%
# ⏳ Early stopping 대기 카운트: 24/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 93/100: 100%|██████████| 96/96 [00:01<00:00, 69.46it/s]
# ✅ Train Epoch 93 Finished - Avg Loss: 0.6193, Avg Acc: 79.16%
# ✅ Validation Finished - Avg Loss: 0.5214, Avg Acc: 84.14%
# ⏳ Early stopping 대기 카운트: 25/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 94/100: 100%|██████████| 96/96 [00:01<00:00, 79.91it/s]
# ✅ Train Epoch 94 Finished - Avg Loss: 0.6168, Avg Acc: 79.51%
# ✅ Validation Finished - Avg Loss: 0.5227, Avg Acc: 84.10%
# ⏳ Early stopping 대기 카운트: 26/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 95/100: 100%|██████████| 96/96 [00:01<00:00, 80.96it/s]
# ✅ Train Epoch 95 Finished - Avg Loss: 0.6177, Avg Acc: 79.29%
# ✅ Validation Finished - Avg Loss: 0.5216, Avg Acc: 84.14%
# ⏳ Early stopping 대기 카운트: 27/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 96/100: 100%|██████████| 96/96 [00:01<00:00, 79.65it/s]
# ✅ Train Epoch 96 Finished - Avg Loss: 0.6205, Avg Acc: 79.35%
# ✅ Validation Finished - Avg Loss: 0.5216, Avg Acc: 84.14%
# ⏳ Early stopping 대기 카운트: 28/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 97/100: 100%|██████████| 96/96 [00:01<00:00, 79.07it/s]
# ✅ Train Epoch 97 Finished - Avg Loss: 0.6211, Avg Acc: 79.16%
# ✅ Validation Finished - Avg Loss: 0.5223, Avg Acc: 84.07%
# ⏳ Early stopping 대기 카운트: 29/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 98/100: 100%|██████████| 96/96 [00:01<00:00, 81.80it/s]
# ✅ Train Epoch 98 Finished - Avg Loss: 0.6210, Avg Acc: 79.32%
# ✅ Validation Finished - Avg Loss: 0.5222, Avg Acc: 84.07%
# ⏳ Early stopping 대기 카운트: 30/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 99/100: 100%|██████████| 96/96 [00:01<00:00, 81.37it/s]
# ✅ Train Epoch 99 Finished - Avg Loss: 0.6219, Avg Acc: 79.33%
# ✅ Validation Finished - Avg Loss: 0.5225, Avg Acc: 84.14%
# ⏳ Early stopping 대기 카운트: 31/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv
# Epoch 100/100: 100%|██████████| 96/96 [00:01<00:00, 72.11it/s]
# ✅ Train Epoch 100 Finished - Avg Loss: 0.6215, Avg Acc: 79.39%
# ✅ Validation Finished - Avg Loss: 0.5229, Avg Acc: 84.10%
# ⏳ Early stopping 대기 카운트: 32/50
# 💾 Training results saved at /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.csv

# %% [markdown]
# ## 결과 시각화

# %%
def analyze_misclassified_samples(model, test_sequences, test_labels, metadata):
    """
    모델이 틀린 샘플의 정보를 분석하는 함수.

    Args:
        model (torch.nn.Module): 학습된 모델.
        test_sequences (torch.Tensor): 테스트 데이터 시퀀스.
        test_labels (torch.Tensor): 실제 라벨.
        metadata (list): 각 시퀀스의 메타데이터 (label, group_key, sequence_index).

    Returns:
        None
    """
    model.eval()  # 평가 모드로 전환

    with torch.no_grad():
        predictions = model(test_sequences).argmax(dim=1)  # 모델 예측값

        misclassified_indices = (predictions != test_labels).nonzero(as_tuple=True)[0]  # 틀린 샘플의 인덱스

        print("📊 틀린 샘플 정보:")
        for idx in misclassified_indices:
            true_label = int(test_labels[idx].item())
            predicted_label = int(predictions[idx].item())
            label_name = label_mapping_inverse[true_label]
            predicted_name = label_mapping_inverse[predicted_label]

            meta_info = metadata[idx]
            print(f" - True Label: {label_name}, Predicted: {predicted_name}, Group Key: {meta_info[1]}, Sequence Index: {meta_info[2]}")

# %%
# Train 성능 평가만 할 경우
def plot_train_results(epoch_losses, epoch_scores, save_path="./"):
    """
    학습 과정의 Loss 및 Accuracy를 시각화하는 함수 (Train만).
    """
    os.makedirs(save_path, exist_ok=True)

    A = np.array(epoch_losses)
    B = np.array(epoch_scores)

    fig = plt.figure(figsize=(10, 4))

    # Loss 그래프
    plt.subplot(121)
    plt.plot(np.arange(1, len(A) + 1), A, marker="o", markersize=2, linestyle="-", label="Train Loss")
    plt.title("Model Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend(loc="upper left")
    plt.ylim((0, max(2, max(A)))) # Y축 범위 설정

    # Accuracy 그래프
    plt.subplot(122)
    plt.plot(np.arange(1, len(B) + 1), B, marker="o", markersize=2, linestyle="-", label="Train Accuracy")
    plt.title("Training Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy (%)")
    plt.legend(loc="upper left")
    plt.ylim((0, 100))

    # 그래프 저장
    plot_save_path = os.path.join(save_path, "train_results.png")
    plt.savefig(plot_save_path, dpi=600)
    plt.show()

    print(f"\n✅ 학습 그래프 저장 완료 ({plot_save_path})\n")

# Train - Test 성능 평가 (Train + Validation)
def plot_train_test_results(
    epoch_train_losses,
    epoch_train_scores,
    epoch_test_losses,
    epoch_test_scores,
    save_path="./"
    ):
    """
    학습 및 검증 과정의 Loss 및 Accuracy를 시각화하는 함수 (Train + Test).
    """
    os.makedirs(save_path, exist_ok=True)

    A = np.array(epoch_train_losses)
    B = np.array(epoch_train_scores)
    C = np.array(epoch_test_losses)
    D = np.array(epoch_test_scores)

    fig = plt.figure(figsize=(10, 4))

    # Loss 그래프
    plt.subplot(121)
    plt.plot(np.arange(1, len(A) + 1), A, marker="o", markersize=2, linestyle="-", label="Train Loss")
    plt.plot(np.arange(1, len(C) + 1), C, marker="s", markersize=2, linestyle="--", label="Test Loss")
    plt.title("Model Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend(loc="upper left")
    plt.ylim((0, max(2, max(A), max(C))))

    # Accuracy 그래프
    plt.subplot(122)
    plt.plot(np.arange(1, len(B) + 1), B, marker="o", markersize=2, linestyle="-", label="Train Accuracy")
    plt.plot(np.arange(1, len(D) + 1), D, marker="s", markersize=2, linestyle="-", label="Test Accuracy")
    plt.title("Training vs Validation Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy (%)")
    plt.legend(loc="upper left")
    plt.ylim((0, 100))

    # 그래프 저장
    plot_save_path = os.path.join(save_path, "training_results.png")
    plt.savefig(plot_save_path, dpi=600)
    plt.show()

    print(f"\n✅ 학습 및 검증 그래프 저장 완료 ({plot_save_path})\n")

# %%
plot_train_results(epoch_losses, epoch_scores, config["train_result_path"])
# Out:
# ✅ 학습 그래프 저장 완료 (/content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/train_results.png)

# %%
plot_train_test_results(
    epoch_train_losses,
    epoch_train_scores,
    epoch_test_losses,
    epoch_test_scores,
    save_path=config["train_result_path"],
)
# Out:
# ✅ 학습 및 검증 그래프 저장 완료 (/content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/train_results/training_results.png)

# %% [markdown]
# ### 마지막 학습률 확인

# %%
def get_current_lr(optimizer):
    return [param_group["lr"] for param_group in optimizer.param_groups]

current_lr = get_current_lr(optimizer)
print(f"🚀 현재 Learning Rate: {current_lr}")
# Out:
# 🚀 현재 Learning Rate: [1.220703125e-08]

# %%
scheduler.get_last_lr()
# Out:
# [1.220703125e-08]

# %% [markdown]
# ### confusion matrix 시각화

# %%
# 모델 로드 함수
def load_model(model, model_save_path, device):
    """저장된 모델을 불러오는 함수"""
    checkpoint = torch.load(model_save_path, map_location=device)
    model.load_state_dict(checkpoint["model_state_dict"])
    model.to(device)
    model.eval()
    print(f"✅ Model Loaded from {model_save_path}")
    return model

# Confusion Matrix 시각화 함수
def plot_confusion_matrix(y_true, y_pred):
    """
    Confusion Matrix를 그리는 함수
    """
    # 숫자 레이블을 글씨로 변환
    class_names = [label_mapping_inverse[i] for i in sorted(label_mapping_inverse.keys())]

    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix")
    plt.show()

    print("\n🔹 Classification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names))

# 학습 데이터에서 Confusion Matrix 계산
def evaluate_model(model, data_loader, class_names):
    """
    모델을 평가하고 Confusion Matrix를 출력하는 함수
    """
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for x_batch, y_batch in data_loader:
            x_batch, y_batch = x_batch.to("cuda"), y_batch.to("cuda")

            y_pred = model(x_batch)  # (batch_size, num_classes)
            y_pred_classes = torch.argmax(y_pred, dim=1)  # 가장 높은 확률을 가진 클래스를 예측값으로 선택

            all_preds.extend(y_pred_classes.cpu().numpy())
            all_labels.extend(y_batch.cpu().numpy())

    # Confusion Matrix 출력
    plot_confusion_matrix(all_labels, all_preds)

# %%
model = load_model(model, "/content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth", device)
class_names = config['action_names']
evaluate_model(model, train_loader, class_names)
# Out:
# ✅ Model Loaded from /content/drive/MyDrive/DMS/data/model_results/031612_4s_sliding/best_model_2025-03-16.pth
# 🔹 Classification Report:
#               precision    recall  f1-score   support
#
#       normal       0.73      0.85      0.79      1129
#    phonecall       0.86      0.86      0.86      1015
#         text       0.81      0.85      0.83       712
#         yawn       0.00      0.00      0.00       215
#
#     accuracy                           0.79      3071
#    macro avg       0.60      0.64      0.62      3071
# weighted avg       0.74      0.79      0.77      3071

# %%
evaluate_model(model, test_loader, class_names)
# Out:
# 🔹 Classification Report:
#               precision    recall  f1-score   support
#
#       normal       0.90      0.87      0.88       493
#    phonecall       0.87      0.97      0.92       229
#         text       0.55      0.74      0.63        96
#         yawn       0.00      0.00      0.00        38
#
#     accuracy                           0.84       856
#    macro avg       0.58      0.64      0.61       856
# weighted avg       0.81      0.84      0.83       856

# %% [markdown]
# # 2. 테스트 코드
# 1. **동영상에서 프레임 추출**
# 2. **12개씩 프레임 묶음 (시퀀스 단위)**
# 3. **특징 추출 (Pitch, Yaw, EAR, MAR, Phone 사용 여부)**
# 4. **특징값 병합**
# 5. **LSTM Input 형식 변환**
# 6. **LSTM 모델 예측 (테스트 수행)**

# %%
import os
import numpy as np

def merge_video_parts_to_24frames(data_dir, save_dir):
    """
    한 비디오의 여러 `part-*` 파일들을 순서대로 합쳐 24프레임씩 묶어 저장하는 함수.

    Args:
        data_dir (str): 기존 12프레임 묶음 데이터가 저장된 디렉토리.
        save_dir (str): 24프레임으로 변환된 데이터를 저장할 디렉토리.
    """
    os.makedirs(save_dir, exist_ok=True)  # 저장할 디렉토리 생성

    # ✅ 12프레임 묶음 파일 리스트 가져오기
    all_files = sorted(os.listdir(data_dir))  # 파일 이름 기준 정렬
    video_dict = {}

    # ✅ 비디오별로 `part-*`를 그룹화
    for file in all_files:
        if not file.endswith(".npz"):  # ✅ npz 파일이 아니면 스킵
            continue
        video_name, part = file.rsplit("_", 1)  # ✅ 비디오 이름과 `part-*` 분리
        video_dict.setdefault(video_name, []).append(file)

    # ✅ 각 비디오별로 `part-*`들을 24프레임 단위로 묶어서 저장
    for video_name, parts in video_dict.items():
        parts.sort()  # ✅ part 순서대로 정렬
        merged_features = []
        merged_labels = []
        part_count = 0

        for part_file in parts:
            part_data = np.load(os.path.join(data_dir, part_file), allow_pickle=True)

            # ✅ 기존 12프레임 데이터 추가
            merged_features.append(part_data["features"])
            merged_labels.append(part_data["labels"])

            # ✅ 24프레임이 채워졌을 경우 저장
            if len(merged_features) == 2:  # 12프레임 x 2 = 24프레임
                full_features = np.concatenate(merged_features, axis=0)
                full_labels = np.concatenate(merged_labels, axis=0)

                # ✅ 저장할 파일명 생성
                merged_file_name = f"{video_name}_merged-{part_count}.npz"
                save_path = os.path.join(save_dir, merged_file_name)

                # ✅ 데이터 저장
                np.savez_compressed(save_path, features=full_features, labels=full_labels)
                print(f"✅ Saved: {save_path}")

                # ✅ 초기화
                merged_features = []
                merged_labels = []
                part_count += 1

        # ✅ 남은 데이터(12프레임 미만)도 저장
        if merged_features:
            remaining_features = np.concatenate(merged_features, axis=0)
            remaining_labels = np.concatenate(merged_labels, axis=0)

            remaining_file_name = f"{video_name}_merged-{part_count}.npz"
            save_path = os.path.join(save_dir, remaining_file_name)
            np.savez_compressed(save_path, features=remaining_features, labels=remaining_labels)
            print(f"✅ Saved (Remaining): {save_path}")

    print("🎉 모든 비디오의 `part-*`를 24프레임 단위로 변환 완료!")

# ✅ 변환 실행 예제
data_dir = "/content/drive/MyDrive/DMS/12_frame_batches"
save_dir = "/content/drive/MyDrive/DMS/24_frame_batches"

merge_video_parts_to_24frames(data_dir, save_dir)

# %%
train.head(50)

# %%
train.video_name[23]

# %%
train.video_name[24]

# %%
video_names = train['video_name']
video_clip = []
parts = []
for video_name in video_names:
    splited = video_name.split('_')
    part = splited[-1][4:]
    parts.append(part)
    video_clip.append(''.join(splited[:-1]))
train['part'] = parts
train['video_clip'] = video_clip

# %%
train.info()

# %%
train[20:30]

# %%
timestep = 24

grouped = train.groupby("video_clip")
sequences = []

for _, group in grouped:
    group = group.sort_values(by="frame")  # 프레임 순서 정렬
    features = group[["pitch", "yaw", "avg_EAR", "MAR"]].values
    labels = group["label"].values

    num_samples = len(features) // timestep  # 가능한 샘플 개수
    features = features[:num_samples * timestep]  # 24 프레임 단위로 자르기
    labels = labels[:num_samples * timestep]  # 라벨도 동일하게 자르기

    # (샘플 개수, 24, 특성 수) 형태로 변환
    features = features.reshape(num_samples, timestep, -1)

# %%
sequences

# %%
group

# %%
features

# %%
labels

# %%
group
